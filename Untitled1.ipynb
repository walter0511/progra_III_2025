# %% [markdown]
# <a href="https://colab.research.google.com/github/walter0511/progra_III_2025/blob/librerias/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
ruta = "/content/edad.csv"
notas = pd.read_csv(ruta, sep=";" , encoding="utf-8")
edad = pd.read_csv(ruta, sep=";" , encoding="utf-8")

# %% [markdown]
# EJERCICIO en python realizar la clasificacion de edades de los alumnos cuantos son mayores de edad y cuantos son menores de edad.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
edad['estado'] = edad['edad'].apply(lambda n: 'mayor de edad' if n >= 18 else 'menor de edad')

# %%
sns.set(style="whitegrid")
sns.countplot(data=edad, x='estado', hue='estado', palette={'menor de edad': 'green', 'mayor de edad': 'red'}, legend=False)
plt.title('Alumnos mayores o menor de edad')
plt.xlabel('Estado')
plt.ylabel('Cantidad de alumnos')
plt.show()

# %%
print(edad)
# Out:
#   alumnos   edad  notas
# 0    bryan    10      5
# 1    juan     13      8
# 2     luis    11      9
# 3   angel     18     10
# 4    oscar    22      4
# 5    mauri    11      5
# 6   walter    10      7
# 7   steven    12      5

# %% [markdown]
# Entrenar una IA con lalibreria de tensorflow

# %%
import tensorflow as tf
import pandas as pd
import numpy as np

# %%
grados = pd.read_csv("/content/kelvin.csv", sep=";", encoding="utf-8")
print(grados, grados["k"])
# Out:
#      c       k
# 0  -50  223.15
# 1  -40  233.15
# 2  -30  243.15
# 3  -20  253.15
# 4  -10  263.15
# 5   -9  264.15
# 6   -8  265.15
# 7   -7  266.15
# 8   -6  267.15
# 9   -5  268.15
# 10  -4  169.15
# 11  -3  270.15
# 12  -2  271.15
# 13  -1  272.15
# 14   0  273.15
# 15   1  274.15
# 16   2  275.15
# 17   3  276.15
# 18   4  277.15
# 19   5  278.15
# 20   6  279.15
# 21   7  280.15
# 22   8  281.15
# 23   9  282.15
# 24  10  283.15
# 25  20  293.15
# 26  30  303.15
# 27  40  313.15
# 28  50  323.15 0     223.15
# 1     233.15
# 2     243.15
# 3     253.15
# 4     263.15
# 5     264.15
# 6     265.15
# 7     266.15
# 8     267.15
# 9     268.15
# 10    169.15
# 11    270.15
# 12    271.15
# 13    272.15
# 14    273.15
# 15    274.15
# 16    275.15
# 17    276.15
# 18    277.15
# 19    278.15
# 20    279.15
# 21    280.15
# 22    281.15
# 23    282.15
# 24    283.15
# 25    293.15
# 26    303.15
# 27    313.15
# 28    323.15
# Name: k, dtype: float64

# %%
c = grados["c"]
k = grados["k"]

print(c,k)
# Out:
# 0    -50
# 1    -40
# 2    -30
# 3    -20
# 4    -10
# 5     -9
# 6     -8
# 7     -7
# 8     -6
# 9     -5
# 10    -4
# 11    -3
# 12    -2
# 13    -1
# 14     0
# 15     1
# 16     2
# 17     3
# 18     4
# 19     5
# 20     6
# 21     7
# 22     8
# 23     9
# 24    10
# 25    20
# 26    30
# 27    40
# 28    50
# Name: c, dtype: int64 0     223.15
# 1     233.15
# 2     243.15
# 3     253.15
# 4     263.15
# 5     264.15
# 6     265.15
# 7     266.15
# 8     267.15
# 9     268.15
# 10    169.15
# 11    270.15
# 12    271.15
# 13    272.15
# 14    273.15
# 15    274.15
# 16    275.15
# 17    276.15
# 18    277.15
# 19    278.15
# 20    279.15
# 21    280.15
# 22    281.15
# 23    282.15
# 24    283.15
# 25    293.15
# 26    303.15
# 27    313.15
# 28    323.15
# Name: k, dtype: float64

# %%
modelo = tf.keras.Sequential()
modelo.add(tf.keras.layers.Dense(units=1, input_shape=[1]))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
modelo.compile(optimizer=tf.keras.optimizers.Adam(0.01), loss='mean_squared_error')

# %%
epocas = modelo.fit(c, k, epochs=200, verbose=1)
# Out:
# Epoch 1/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 535ms/step - loss: 74724.6641
# Epoch 2/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 74703.0625
# Epoch 3/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 74681.5547
# Epoch 4/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 74660.1172
# Epoch 5/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 74638.7734
# Epoch 6/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 74617.5156
# Epoch 7/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 74596.3438
# Epoch 8/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 74575.2578
# Epoch 9/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 74554.2578
# Epoch 10/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 74533.3594
# Epoch 11/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 74512.5547
# Epoch 12/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 74491.8281
# Epoch 13/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 74471.2031
# Epoch 14/200
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
g = int(input("Celsius: "))
resp = modelo.predict(np.array([g]))
print("kelvin: ", resp[0][0])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3365474000.py in <cell line: 0>()
# ----> 1 g = int(input("Celsius: "))
#       2 resp = modelo.predict(np.array([g]))
#       3 print("kelvin: ", resp[0][0])
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
#guardar modelo
modelo.save("grados.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
